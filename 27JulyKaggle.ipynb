# %%
import pandas as pd
ingredients = pd.DataFrame([['Flour', '4 cups'],['Milk', '1 cup'], ['Eggs', '2 large'], ['Spam' , '1 can']])
ingredients
# Out:
#        0        1
# 0  Flour   4 cups
# 1   Milk    1 cup
# 2   Eggs  2 large
# 3   Spam    1 can

# %%
quantities = ['4 cups', '1 cup', '2 large', '1 can']
items = ['Flour', 'Milk', 'Eggs', 'Spam']
recipe = pd.Series(quantities, index=items, name='Dinner')
recipe
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object
